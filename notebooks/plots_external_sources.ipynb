# %%
#import libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# %%
#mount drive
from google.colab import drive
drive.mount('1LbVccBPxo8pR9C41wosD5qYOglKsDrPr')
# Out:
# Drive already mounted at 1LbVccBPxo8pR9C41wosD5qYOglKsDrPr; to attempt to forcibly remount, call drive.mount("1LbVccBPxo8pR9C41wosD5qYOglKsDrPr", force_remount=True).

# %%
#import processed dataset
df = pd.read_csv("/content/1LbVccBPxo8pR9C41wosD5qYOglKsDrPr/MyDrive/001_Masterarbeit/illustrations/Google Search Timeline AI.csv", index_col=0, header = 1)

# %%
#basic setting for plot layout
sns.set_theme(style="whitegrid")
plt.rcParams.update({'font.size': 22})

my_colors = 'muted' #alt: "ch:r=-.2,d=.3_r"

# %%
# Draw a scatter plot while assigning point colors and sizes to different variables in the dataset
f, ax = plt.subplots(figsize=(16.5, 10.5))
sns.despine(f, left=True, bottom=True)

p = sns.lineplot(data = df,
                      palette = my_colors,
                      linewidth = 2,
                      marker='o',
                      linestyle= '--')

p.set_ylim(0, 100)
p.set_ylabel('Serach Interest')
p.set_xlabel('Week (2018.09.30 - 2023.09.24)')
p.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
# Out:
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
# WARNING:matplotlib.font_manager:findfont: Generic family 'monospace' not found because none of the following families were found: FreeMono
